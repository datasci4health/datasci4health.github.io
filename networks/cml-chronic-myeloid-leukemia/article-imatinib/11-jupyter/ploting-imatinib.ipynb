# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g_imatinib = nx.read_edgelist("./490-nodes-up-1-neo4j-edges.csv", delimiter=",")

# %%
nx.draw(g_imatinib)

# %%
nx.write_pajek(g_imatinib, "490-nodes-up-1-neo4j-edges.net")
